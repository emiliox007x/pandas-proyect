# %%
import pandas as pd
import numpy as np
import re
data=pd.read_csv("GSAF5.csv",engine="python")

# %%
#tamaño de la base de datos
data.shape
# Out:
# (5992, 24)

# %%
#ver las estadisticas
data.describe()
# Out:
#               Year  original order
# count  5992.000000     5992.000000
# mean   1925.204606     2997.548899
# std     286.473712     1729.860210
# min       0.000000        2.000000
# 25%    1942.000000     1499.750000
# 50%    1975.000000     2997.500000
# 75%    2003.000000     4495.250000
# max    2016.000000     5993.000000

# %%
#examinando la base de datos
data.head
# Out:
# <bound method NDFrame.head of        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 24 columns):
# Case Number               5992 non-null object
# Date                      5992 non-null object
# Year                      5992 non-null int64
# Type                      5992 non-null object
# Country                   5949 non-null object
# Area                      5590 non-null object
# Location                  5496 non-null object
# Activity                  5465 non-null object
# Name                      5792 non-null object
# Sex                       5425 non-null object
# Age                       3311 non-null object
# Injury                    5965 non-null object
# Fatal (Y/N)               5973 non-null object
# Time                      2779 non-null object
# Species                   3058 non-null object
# Investigator or Source    5977 non-null object
# pdf                       5992 non-null object
# href formula              5991 non-null object
# ...

# %%
#ver el nombre de las columnas
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
#eliminando duplicados
data.drop_duplicates()
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
#comprovamos los valores nulos de las columnas

null_cols=data.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# href formula                 1
# href                         3
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
#miramos 2 columnas solo

data[['Unnamed: 22', 'Unnamed: 23']].head()
# Out:
#   Unnamed: 22 Unnamed: 23
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
#sort values:
data.sort_values(['Unnamed: 22','Unnamed: 23'], ascending=False)
# Out:
#        Case Number                                               Date  Year  \
# 1247    2006.06.18                                          18-Jun-06  2006
# 5585    1879.03.10                                        10-Mar-1879  1879
# 4182    1952.07.13                                          13-Jul-52  1952
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# ...

# %%
#accedo a la fila 1 para ver su contenido
data.loc [1]
# Out:
# Case Number                                                    2016.09.18.b
# Date                                                              18-Sep-16
# Year                                                                   2016
# Type                                                             Unprovoked
# Country                                                                 USA
# Area                                                                Florida
# Location                                   New Smyrna Beach, Volusia County
# Activity                                                            Surfing
# Name                                                         Chucky Luciano
# Sex                                                                       M
# Age                                                                      36
# Injury                                                 Lacerations to hands
# ...

# %%
#describe la columna numerica "Year"
data["Year"].describe()
# Out:
# count    5992.000000
# mean     1925.204606
# std       286.473712
# min         0.000000
# 25%      1942.000000
# 50%      1975.000000
# 75%      2003.000000
# max      2016.000000
# Name: Year, dtype: float64

# %%
#nos muesta el indice de la tabla
data.index
# Out:
# RangeIndex(start=0, stop=5992, step=1)

# %%
display(data["Year"])
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2016
# 4       2016
# 5       2016
# 6       2016
# 7       2016
# 8       2016
# 9       2016
# 10      2016
# 11      2016
# 12      2016
# 13      2016
# 14      2016
# 15      2016
# 16      2016
# 17      2016
# 18      2016
# 19      2016
# 20      2016
# 21      2016
# 22      2016
# 23      2016
# 24      2016
# 25      2016
# 26      2016
# 27      2016
# 28      2016
# 29      2016
#         ...
# 5962       0
# 5963       0
# 5964       0
# 5965       0
# 5966       0
# 5967       0
# 5968       0
# 5969       0
# 5970       0
# 5971       0
# 5972       0
# 5973       0
# 5974       0
# 5975       0
# 5976       0
# 5977       0
# 5978       0
# 5979       0
# 5980       0
# 5981       0
# 5982       0
# 5983       0
# 5984       0
# 5985       0
# 5986       0
# 5987       0
# 5988       0
# 5989       0
# 5990       0
# 5991       0
# Name: Year, Length: 5992, dtype: int64

# %%
#ver que elemntos tiene la columna "Year"
data["Year"].unique()
# Out:
# array([2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006,
#        2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995,
#        1984, 1994, 1993, 1992, 1991, 1990, 1989, 1969, 1988, 1987, 1986,
#        1985, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976, 1975, 1974,
#        1973, 1972, 1971, 1970, 1968, 1967, 1966, 1965, 1964, 1963, 1962,
#        1961, 1960, 1959, 1958, 1957, 1956, 1955, 1954, 1953, 1952, 1951,
#        1950, 1949, 1948, 1848, 1947, 1946, 1945, 1944, 1943, 1942, 1941,
#        1940, 1939, 1938, 1937, 1936, 1935, 1934, 1933, 1932, 1931, 1930,
#        1929, 1928, 1927, 1926, 1925, 1924, 1923, 1922, 1921, 1920, 1919,
#        1918, 1917, 1916, 1915, 1914, 1913, 1912, 1911, 1910, 1909, 1908,
#        1907, 1906, 1905, 1904, 1903, 1902, 1901, 1900, 1899, 1898, 1897,
#        1896, 1895, 1894, 1893, 1892, 1891, 1890, 1889, 1888, 1887, 1886,
#        1885, 1884, 1883, 1882, 1881, 1880, 1879, 1878, 1877, 1876, 1875,
# ...

# %%
#contar los valores unicos
data["Year"].nunique()
# Out:
# 232

# %%
#numero de valores unicos ordenados de mayor a menor
data["Year"].value_counts(sort=True).head()
# Out:
# 2015    139
# 2011    128
# 2014    125
# 0       124
# 2013    122
# Name: Year, dtype: int64

# %%
data["Country"].value_counts(sort=True)
# Out:
# USA                             2116
# AUSTRALIA                       1279
# SOUTH AFRICA                     565
# PAPUA NEW GUINEA                 133
# NEW ZEALAND                      125
# BRAZIL                           102
# BAHAMAS                           98
# MEXICO                            81
# ITALY                             71
# FIJI                              62
# PHILIPPINES                       59
# REUNION                           57
# NEW CALEDONIA                     51
# MOZAMBIQUE                        44
# CUBA                              42
# SPAIN                             40
# INDIA                             37
# EGYPT                             36
# CROATIA                           34
# JAPAN                             32
# PANAMA                            32
# SOLOMON ISLANDS                   29
# IRAN                              29
# GREECE                            25
# HONG KONG                         24
# ...

# %%
#voy a limpiar los valores NaN de la columna Fatal (Y/N) que utilzare para spain
data.iloc[5699]#voy a colocarlo como Fatal (Y), descripcion de la lesion: posible ahogamiento
data.iloc[5794]#voy a ponerlo como Fatal (Y), descripcion: encontraron restos humanos dentro de un tiburon
data["Fatal (Y/N)"] = data["Fatal (Y/N)"].fillna(value="Y") 
spain["Fatal (Y/N)"].replace(0, "Y")
# Out:
# 20      N
# 34      N
# 104     N
# 159     N
# 249     N
# 282     N
# 287     N
# 307     N
# 434     N
# 788     N
# 884     N
# 1234    N
# 2251    N
# 2596    N
# 2597    N
# 2834    N
# 3184    N
# 3633    N
# 4808    N
# 4834    N
# 4918    N
# 4932    N
# 4956    N
# 5076    N
# 5143    Y
# 5150    Y
# 5185    N
# 5196    Y
# 5197    Y
# 5581    N
# 5683    Y
# 5698    N
# 5699    Y
# 5700    Y
# 5701    Y
# 5702    Y
# 5794    Y
# 5819    N
# 5842    Y
# 5887    N
# Name: Fatal (Y/N), dtype: object

# %%
#creo tabla con los ataques en España
spain=data[data["Country"]=="SPAIN"]
spain
# Out:
#        Case Number                  Date  Year        Type Country  \
# 20      2016.07.29             29-Jul-16  2016  Unprovoked   SPAIN
# 34    2016.07.08.R  Reported 08-Jul-2016  2016  Unprovoked   SPAIN
# 104     2015.12.25             25-Dec-15  2015  Unprovoked   SPAIN
# 159   2015.08.18.a             18-Aug-15  2015     Invalid   SPAIN
# 249   2014.12.03.R  Reported 03-Dec-2014  2014    Provoked   SPAIN
# 282     2014.09.00                Sep-14  2014  Unprovoked   SPAIN
# 287   2014.08.27.c             27-Aug-14  2014  Unprovoked   SPAIN
# 307     2014.07.20             20-Jul-14  2014  Unprovoked   SPAIN
# 434     2013.07.09             07-Jul-13  2013     Invalid   SPAIN
# 788   2010.07.16.b             16-Jul-10  2010    Provoked   SPAIN
# 884   2009.07.24.a             24-Jul-09  2009     Invalid   SPAIN
# 1234    2006.07.13             13-Jul-06  2006     Invalid   SPAIN
# 2251    1993.09.03             03-Sep-93  1993  Unprovoked   SPAIN
# ...

# %%
spain= spain.iloc[:, [1,2,3,4,5,7,9,11,12,14]]
spain
# Out:
#                       Date  Year        Type Country                 Area  \
# 20               29-Jul-16  2016  Unprovoked   SPAIN    Alicante Province
# 34    Reported 08-Jul-2016  2016  Unprovoked   SPAIN       Canary Islands
# 104              25-Dec-15  2015  Unprovoked   SPAIN  Grand Canary Island
# 159              18-Aug-15  2015     Invalid   SPAIN             Alicante
# 249   Reported 03-Dec-2014  2014    Provoked   SPAIN              Granada
# 282                 Sep-14  2014  Unprovoked   SPAIN            Catalonia
# 287              27-Aug-14  2014  Unprovoked   SPAIN             Alicante
# 307              20-Jul-14  2014  Unprovoked   SPAIN       Canary Islands
# 434              07-Jul-13  2013     Invalid   SPAIN            Catalonia
# 788              16-Jul-10  2010    Provoked   SPAIN  Grand Canary Island
# 884              24-Jul-09  2009     Invalid   SPAIN            Catalunya
# 1234             13-Jul-06  2006     Invalid   SPAIN             Alicante
# ...

# %%
spain["Area"].value_counts()
# Out:
# Canary Islands         7
# Catalonia              4
# C�diz                  3
# Alicante               3
# Malaga                 2
# Valencia               2
# Grand Canary Island    2
# Balearics              1
# Andalucia              1
# Galica                 1
# Granada                1
# Costa Blanca           1
# Gran Canaria           1
# Eastern Catalona       1
# Catalunya              1
# M�laga                 1
# Galicia                1
# Valencia               1
# Alicante Province      1
# Sants-Montjic          1
# Name: Area, dtype: int64

# %%
#modifico la columna para poder luego agrupar los elementos por CCAA
spain=spain.replace(to_replace ="C�diz", value ="Cadiz") 
spain=spain.replace(to_replace ="Valencia ", value ="Valencia") 
spain=spain.replace(to_replace ="Galica", value ="Galicia")
spain=spain.replace(to_replace =["M�laga", "M�laga "],value ="Malaga")
spain=spain.replace(to_replace ="Alicante Province", value ="Alicante")
spain["Area"].value_counts()
# Out:
# Canary Islands         7
# Catalonia              4
# Alicante               4
# Valencia               3
# Malaga                 3
# Cadiz                  3
# Grand Canary Island    2
# Galicia                2
# Costa Blanca           1
# Eastern Catalona       1
# Catalunya              1
# Gran Canaria           1
# Granada                1
# Balearics              1
# Andalucia              1
# Sants-Montjic          1
# Name: Area, dtype: int64

# %%
CCAA= {
    "Canary Islands":"Canary Islands",
    "Catalonia":"Catalunya",
    "Cadiz":"Andalucia",
    "Malaga":"Andalucia",
    "Alicante":"Valencia",
    "Valencia":"Valencia",
    "Galicia":"Galicia",
    "Grand Canary Island":"Canary Islands",
    "Catalunya":"Catalunya",
    "Granada":"Andalucia",
    "Andalucia":"Andalucia",
    "Costa Blanca":"Valencia",
    "Sants-Montjic":"Catalunya",
    "Balearics":"Balearics Islands",
    "Gran Canaria":"Canary Islands",
    "Eastern Catalona":"Catalunya"
}

# %%
spain["CCAA"]=spain["Area"].map(CCAA)
display(spain)
# Out:
#                       Date  Year        Type Country                 Area  \
# 20               29-Jul-16  2016  Unprovoked   SPAIN             Alicante
# 34    Reported 08-Jul-2016  2016  Unprovoked   SPAIN       Canary Islands
# 104              25-Dec-15  2015  Unprovoked   SPAIN  Grand Canary Island
# 159              18-Aug-15  2015     Invalid   SPAIN             Alicante
# 249   Reported 03-Dec-2014  2014    Provoked   SPAIN              Granada
# 282                 Sep-14  2014  Unprovoked   SPAIN            Catalonia
# 287              27-Aug-14  2014  Unprovoked   SPAIN             Alicante
# 307              20-Jul-14  2014  Unprovoked   SPAIN       Canary Islands
# 434              07-Jul-13  2013     Invalid   SPAIN            Catalonia
# 788              16-Jul-10  2010    Provoked   SPAIN  Grand Canary Island
# 884              24-Jul-09  2009     Invalid   SPAIN            Catalunya
# 1234             13-Jul-06  2006     Invalid   SPAIN             Alicante
# ...

# %%
#ataque por provincia
spain["CCAA"].value_counts(sort=True)
# Out:
# Canary Islands       10
# Andalucia             8
# Valencia              8
# Catalunya             7
# Galicia               2
# Balearics Islands     1
# Name: CCAA, dtype: int64

# %%
#tipo de ataque
spain["Fatal (Y/N)"].value_counts(sort=True)
# Out:
# N    29
# Y    11
# Name: Fatal (Y/N), dtype: int64

# %%
spain["Sex "].value_counts(sort=True)
# Out:
# M    27
# F     7
# Name: Sex , dtype: int64

# %%
#Elimino los espacios en la columna "Activity"
spain["Activity"]=spain["Activity"].str.strip()
spain["Activity"].value_counts()
# Out:
# Swimming                                    12
# Fishing                                      5
# Bathing                                      4
# Diving                                       2
# Wading                                       2
# Skin diving                                  2
# Fell into the water                          1
# Playing with an air mattress                 1
# Swimming alongside the SS Kearsarge          1
# Fishing for blue sharks                      1
# Fell overboard from P&O steamship Arabia     1
# Windsurfing                                  1
# Spearfishing                                 1
# Dangling feet in the water                   1
# Name: Activity, dtype: int64

# %%
spain[["Activity","CCAA","Fatal (Y/N)"]]
# Out:
#                                       Activity               CCAA Fatal (Y/N)
# 20                                    Swimming           Valencia           N
# 34                                      Wading     Canary Islands           N
# 104                                   Swimming     Canary Islands           N
# 159                                   Swimming           Valencia           N
# 249                    Fishing for blue sharks          Andalucia           N
# 282               Playing with an air mattress          Catalunya           N
# 287                                   Swimming           Valencia           N
# 307                                     Wading     Canary Islands           N
# 434                                   Swimming          Catalunya           N
# 788                                   Swimming     Canary Islands           N
# 884                                   Swimming          Catalunya           N
# ...

# %%
#ordenamos los ataques por "Fatal" y "CCAA"
ataques= spain.sort_values(["Fatal (Y/N)","CCAA"])
ataques.head()
# Out:
#                       Date  Year        Type Country                 Area  \
# 249   Reported 03-Dec-2014  2014    Provoked   SPAIN              Granada
# 2597             18-Mar-86  1986  Unprovoked   SPAIN                Cadiz
# 5185  Reported 27-Apr-1909  1909    Provoked   SPAIN            Andalucia
# 34    Reported 08-Jul-2016  2016  Unprovoked   SPAIN       Canary Islands
# 104              25-Dec-15  2015  Unprovoked   SPAIN  Grand Canary Island
#
#                      Activity Sex   \
# 249   Fishing for blue sharks    M
# 2597              Windsurfing    M
# 5185                  Fishing    M
# 34                     Wading    F
# 104                  Swimming    F
#
#                                                  Injury Fatal (Y/N)  \
# 249   Glancing bite to wrist from netted shark PROVO...           N
# 2597                                       Foot severed           N
# 5185  Shark knocked him down after he grabbed it by ...           N
# ...

# %%
sp3=spain.pivot_table("Fatal (Y/N)","CCAA", aggfunc=np.sum)
sp3
# Out:
#                   Fatal (Y/N)
# CCAA
# Andalucia            NNYNYYYY
# Balearics Islands           Y
# Canary Islands     NNNNNNNNYN
# Catalunya             NNNNNNY
# Galicia                    NY
# Valencia             NNNNNNNN

# %%
#miro los values
C=sp3["Fatal (Y/N)"].values
display(C)
# Out:
# array(['NNYNYYYY', 'Y', 'NNNNNNNNYN', 'NNNNNNY', 'NY', 'NNNNNNNN'], dtype=object)

# %%
#saco el porcentaje de muertes
contY = 0
contN = 0
lista =[]
for x in C:
    contY = 0
    contN = 0
    for indice in x:
        if indice=="N":
            contN+=1
        elif indice=="Y":
            contY+=1
    lista.append(contY*100/(contN+contY))
lista
# Out:
# [62.5, 100.0, 10.0, 14.285714285714286, 50.0, 0.0]

# %%
spain2.size().plot.bar()

# %%
#unimos el porcentaje a las comunidades
Comunidades=("Andalucia","Balearics Islands","Canary Islands","Catalunya","Galicia","Valencia")
porcentaje=list(zip(lista, Comunidades))
display(porcentaje)
# Out:
# [(62.5, 'Andalucia'),
#  (100.0, 'Balearics Islands'),
#  (10.0, 'Canary Islands'),
#  (14.285714285714286, 'Catalunya'),
#  (50.0, 'Galicia'),
#  (0.0, 'Valencia')]

# %% [markdown]
# Conclusion: En Baleares hay 100% de posibilidades de que si te ataca un tiburon sea mortal, y en Valencia te salvas al 100%.

# %%
#calculo los porcentajes de vivos y muertos
A=spain2.size().values

nf= A[0]*100/A[0]
print("el porcentaje de mujeres vivas :",nf)    
nm=A[1]*100/(A[1]+A[2])
print("porcentaje de hombres vivos: ",nm)
ym=A[2]*100/(A[1]+A[2])
print ("porcentaje de hombres muertos: ",ym)
# Out:
# el porcentaje de mujeres vivas : 100.0
# porcentaje de hombres vivos:  33.3333333333
# porcentaje de hombres muertos:  66.6666666667

# %% [markdown]
# Conclusion: los ataques de tiburones que se produjeron en costas españolas, el 100% de las mujeres vivieron y de los hombres, el 33% murio.

# %%
#enumero las actividades
spain["Activity"].value_counts(sort=True)
# Out:
# Swimming                                    12
# Fishing                                      5
# Bathing                                      4
# Diving                                       2
# Wading                                       2
# Skin diving                                  2
# Fell into the water                          1
# Playing with an air mattress                 1
# Swimming alongside the SS Kearsarge          1
# Fishing for blue sharks                      1
# Fell overboard from P&O steamship Arabia     1
# Windsurfing                                  1
# Spearfishing                                 1
# Dangling feet in the water                   1
# Name: Activity, dtype: int64

# %% [markdown]
# Conclusion:La actividad que prefieren los tiburones atacar es nadar, seguido de la pesca y el baño.

# %%
#enumero las actividades, distinguiendo si fueron mortales o no
spain2=spain.groupby(["Fatal (Y/N)","Activity"])
spain2.size()
# Out:
# Fatal (Y/N)  Activity
# N            Bathing                                      2
#              Dangling feet in the water                   1
#              Diving                                       2
#              Fishing                                      5
#              Fishing for blue sharks                      1
#              Playing with an air mattress                 1
#              Skin diving                                  2
#              Spearfishing                                 1
#              Swimming                                    10
#              Wading                                       2
#              Windsurfing                                  1
# Y            Bathing                                      2
#              Fell into the water                          1
#              Fell overboard from P&O steamship Arabia     1
#              Swimming                                     2
# ...

# %% [markdown]
# Conclusion: Aunque la actividad mas frecuente de ataque sea nadar(10 ataques fallidos por 3 muertes),
#     es mas peligroso caerse de un barco(0 fallidos por 2 muertes) o bañarse (2 fallidos por 2 muertes)

# %%
export_csv = data.to_csv (r'/home/jose/proyecto ironhack/pandas-proyect/data.csv', index = None, header=True)

# %%
export_csv = spain.to_csv (r'/home/jose/proyecto ironhack/pandas-proyect/spain.csv', index = None, header=True)
